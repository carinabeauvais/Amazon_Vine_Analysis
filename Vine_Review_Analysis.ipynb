# %%
import pandas as pd

# %%
vine_df = pd.read_csv("/vine_table.csv")
vine_df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 0         RGYFDX8QXKEIR          4.0            0.0          0.0    N
# 1        R13CBGTMNV9R8Z          4.0            1.0          2.0    N
# 2         R7DRFHC0F71O0          5.0            0.0          0.0    N
# 3        R27LUKEXU3KBXQ          5.0            1.0          1.0    N
# 4        R1VXTPUYMNU687          5.0            1.0          2.0    N
# ...                 ...          ...            ...          ...  ...
# 5101688   RDI2BF4QD492Y          3.0            1.0          1.0    N
# 5101689  R23UCERX5NG2ZU          1.0            0.0          0.0    N
# 5101690   REXVNT3PZM4YC          5.0            1.0          1.0    N
# 5101691   RUBZ7PGT4XFCG          5.0            4.0          4.0    N
# 5101692  R1KC5WONSFLDOQ          5.0            0.0          0.0    N
#
#         verified_purchase
# 0                       N
# 1                       Y
# 2                       N
# ...

# %%
total_votes = vine_df[(vine_df["total_votes"] >= 20)]
total_votes
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 18       R39ESX43X1SA5T          1.0           36.0         47.0    N
# 26       R31QRZ3JAMPBB4          1.0           16.0         26.0    N
# 90       R23FKBEXURC3SN          5.0           28.0         36.0    N
# 190       R4IAIDV5EE84W          1.0            8.0         21.0    N
# 241      R26MB2DA7ROT4P          1.0            2.0         21.0    N
# ...                 ...          ...            ...          ...  ...
# 5101532  R2AABCEXA6ZUS0          2.0           31.0         37.0    N
# 5101563  R1YGG88TG3770M          5.0           19.0         23.0    N
# 5101596  R1VI5F2N7ZC8EE          1.0           33.0         53.0    N
# 5101632   RCDBF5EIN5KHS          1.0            8.0         51.0    N
# 5101637  R1SPVI2AR5IHGF          1.0           11.0         46.0    N
#
#         verified_purchase
# 18                      Y
# 26                      Y
# 90                      N
# ...

# %%
# get percent of helpful votes
total_votes["helpful_votes_percentage"] = (total_votes["helpful_votes"]) / (total_votes["total_votes"])* 100
total_votes
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 18       R39ESX43X1SA5T          1.0           36.0         47.0    N
# 26       R31QRZ3JAMPBB4          1.0           16.0         26.0    N
# 90       R23FKBEXURC3SN          5.0           28.0         36.0    N
# 190       R4IAIDV5EE84W          1.0            8.0         21.0    N
# 241      R26MB2DA7ROT4P          1.0            2.0         21.0    N
# ...                 ...          ...            ...          ...  ...
# 5101532  R2AABCEXA6ZUS0          2.0           31.0         37.0    N
# ...

# %%
# percents over 50%
over50_votes = total_votes[(total_votes["helpful_votes_percentage"] >= 50)]
over50_votes
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 18       R39ESX43X1SA5T          1.0           36.0         47.0    N
# 26       R31QRZ3JAMPBB4          1.0           16.0         26.0    N
# 90       R23FKBEXURC3SN          5.0           28.0         36.0    N
# 368       RTRVYV0GWUTCK          5.0           18.0         25.0    N
# 394      R3QLZAI37SNOOC          2.0           30.0         31.0    N
# ...                 ...          ...            ...          ...  ...
# 5101525  R12UGECM0W7NU1          1.0           14.0         20.0    N
# 5101528  R3E888STF6AQCC          1.0           30.0         58.0    N
# 5101532  R2AABCEXA6ZUS0          2.0           31.0         37.0    N
# 5101563  R1YGG88TG3770M          5.0           19.0         23.0    N
# 5101596  R1VI5F2N7ZC8EE          1.0           33.0         53.0    N
#
#         verified_purchase  helpful_votes_percentage
# 18                      Y                 76.595745
# ...

# %%
paid_votes = over50_votes[(over50_votes["vine"] == "Y")]
paid_votes
# Out:
# Empty DataFrame
# Columns: [review_id, star_rating, helpful_votes, total_votes, vine, verified_purchase, helpful_votes_percentage]
# Index: []

# %%
unpaid_votes = over50_votes[(over50_votes["vine"] == "N")]
unpaid_votes
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 18       R39ESX43X1SA5T          1.0           36.0         47.0    N
# 26       R31QRZ3JAMPBB4          1.0           16.0         26.0    N
# 90       R23FKBEXURC3SN          5.0           28.0         36.0    N
# 368       RTRVYV0GWUTCK          5.0           18.0         25.0    N
# 394      R3QLZAI37SNOOC          2.0           30.0         31.0    N
# ...                 ...          ...            ...          ...  ...
# 5101525  R12UGECM0W7NU1          1.0           14.0         20.0    N
# 5101528  R3E888STF6AQCC          1.0           30.0         58.0    N
# 5101532  R2AABCEXA6ZUS0          2.0           31.0         37.0    N
# 5101563  R1YGG88TG3770M          5.0           19.0         23.0    N
# 5101596  R1VI5F2N7ZC8EE          1.0           33.0         53.0    N
#
#         verified_purchase  helpful_votes_percentage
# 18                      Y                 76.595745
# ...

# %%
total_paid = paid_votes["review_id"].count()
total_paid
# Out:
# 0

# %%
total_unpaid = unpaid_votes["review_id"].count()
total_unpaid
# Out:
# 65149

# %%
fivestar_paid = paid_votes[(paid_votes["star_rating"] == 5)].count()
fivestar_paid
# Out:
# review_id                   0
# star_rating                 0
# helpful_votes               0
# total_votes                 0
# vine                        0
# verified_purchase           0
# helpful_votes_percentage    0
# dtype: int64

# %%
fivestar_unpaid = unpaid_votes[(unpaid_votes["star_rating"] == 5)].count()
fivestar_unpaid
# Out:
# review_id                   24673
# star_rating                 24673
# helpful_votes               24673
# total_votes                 24673
# vine                        24673
# verified_purchase           24673
# helpful_votes_percentage    24673
# dtype: int64

# %%
percent_paid_fivestar = (fivestar_paid) / (total_paid) *100
percent_paid_fivestar
# Out:
# review_id                  NaN
# star_rating                NaN
# helpful_votes              NaN
# total_votes                NaN
# vine                       NaN
# verified_purchase          NaN
# helpful_votes_percentage   NaN
# dtype: float64

# %%
percent_unpaid_fivestar = (fivestar_unpaid) / (total_unpaid) *100
percent_unpaid_fivestar
# Out:
# review_id                   37.871648
# star_rating                 37.871648
# helpful_votes               37.871648
# total_votes                 37.871648
# vine                        37.871648
# verified_purchase           37.871648
# helpful_votes_percentage    37.871648
# dtype: float64
